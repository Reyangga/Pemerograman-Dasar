# %% [markdown]
# <a href="https://colab.research.google.com/github/Reyangga/Pemerograman-Dasar/blob/main/Unititled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nama = "Reyangga Alvonzo"
Nim = "4232501021"
Umur = 19
Jurusan = "Elektro"
Semester = 3
Matakuliah = 'Pemerograman Dasar'
Status_lulus = False
Tempat_lahir = "Perawang"
Alamat = "Batam  Center"
Email = "reyanggaalvon@gmail.com"
Jenis_kelamin = "Laki Laki"

print (Nama)
print (Nim)
print (Umur)
print (Jurusan)
print (Semester)
print (Matakuliah)
print (Status_lulus)
print (Tempat_lahir)
print (Alamat)
print (Email)
print (Jenis_kelamin)
# Out:
# Reyangga Alvonzo
# 4232501021
# 19
# Elektro
# 3
# Pemerograman Dasar
# False
# Perawang
# Batam  Center
# reyanggaalvon@gmail.com
# Laki Laki
